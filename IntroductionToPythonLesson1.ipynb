# %% [markdown]
# # Introduction to Python: Lesson 1
# ## For Ascension Robotics Club
#
# ### Introduction

# %% [markdown]
# Python is a programming language.  A programming language is a set of instructions (in words and symbols) that tell a computer what to do. Python is a very popular programming language that people use for work and hobbies.  Python is also used to program robots!
#
# This page below will walk you through the basics of the Python language.  This page is called a _notebook_.  It allows you to type in boxes and run code from a webpage!
#
# There are two types of boxes on this page (also called cells).  There are text boxes (like this one) that just display whatever you want to type in them.  There are also code cells (which are darker) which contain code that you can run by clicking the box and then clicking the run button that will appear on the left.
#
# If you want you can add new boxes to the notebook using the buttons at the top of the screen (`+ Code` and `+ Text`).  Go ahead and add a text box below this one by clicking the `+ Text` button and type something in it.

# %% [markdown]
# ### Print Statements
#
# One of the most important things to know how to do is make a computer display something.  In Python, we can do this using the `print` statement followed by a set of parentheses `()`.  The box below shows you how to print words using Python.  Anything that is typed between the single quotes (`'`) will be displayed.  In this case, we are displaying `Hello World`.  You can run the code by clicking the button to the left (looks like a Play button).

# %%
print ('Hello World')
# Out:
# Hello World

# %% [markdown]
# In programming a bunch of letters grouped together is called a _string_.  A string has to appear between single quotes (`'`) so that all of the letters are kept together.  The following are all examples of strings:
# * `'Hello World'`
# * `'Robots'`
# * `'J'` (even single letters can be strings!)
# * `My age is 24` (numbers can also be in a string!)

# %% [markdown]
# Python can also be used to display numbers.  However, for numbers you do not need to use the single quotes (`'`).  For example:

# %%
print(2)

print(45)
# Out:
# 2
# 45

# %% [markdown]
# #### Problem!
# Time to write your own code!  In the box below have Python display your name.  For example, I would type `print('Julie Hartley')` in the box.  In the line below where you are printing your name, print your favorite number.

# %% [markdown]
# ### Math
#
# Python can also be used to do math.  For example, I can type `2+2` in a print statement and it will print the result (`4`).

# %%
print(2 + 2)
# Out:
# 4

# %% [markdown]
# Python can also be used for substraction, multiplication, and division.

# %%
print(3 - 2)

print(4*5)

print(21/3)
# Out:
# 1
# 20
# 7.0

# %% [markdown]
# #### Problem!
#
# In the box below, have Python display the result to your own math expression.

# %% [markdown]
# ### Comments
#
# A *comment* is a line in the code that Python ignores.  You can make a comment by adding a `#` to the beginning of a line.
#
# For example, in the following two lines of code, both `Robot` and `Code` will be printed.

# %%
print('Robot')

print('Code')
# Out:
# Robot
# Code

# %% [markdown]
# However, if I comment out the second line with a `#` then only `Robot` will print.

# %%
print('Robot')

#print('Code')
# Out:
# Robot

# %% [markdown]
# Comments are usually used to explain what your code does.  This is useful if someone else needs to look at your code, or when you come back to your code after not looking at it for awhile.
#
# For example, if I have the following code:

# %%
print('Julie')

print(24)
# Out:
# Julie
# 24

# %% [markdown]
# I could add these comments to it to make the code make more sense when someone else is reading it.

# %%
# Displays my name
print ('Julie')

#Displays my age
print(24)
# Out:
# Julie
# 24

# %% [markdown]
# #### Problem!
#
# In the box below, create your own code, and add a comment to explain what the code does.

# %% [markdown]
# ### Variables
#
# A variable in Python is a placeholder for a number or letters.  Strings (letters) must be between single quotes (`'`) but numbers are not.
#
# To create a variable, first you must choose a name for your variable.  The variable name should be a word that describes what your variable is going to hold.  The more descriptive name the better.
#
# First, type your variable name.  Then type an equal sign.  Then on the right side of the equal sign type the value that your variable should hold.

# %%
#A variable that holds my name
name = 'Julie'

#A variable that holds my current age
age = 24

# %% [markdown]
# The value that is being held in a variable can be displayed using the print statement (just put the name of the variable between the parentheses of the print statement).

# %%
# Display the value stored in the variable name
print(name)

# Display the value stored in the variable age
print(age)
# Out:
# Julie
# 24

# %% [markdown]
# Names for variables must start with a letter, but can also contain underscores `_`.  Typically, an underscore is used to separate words in a variable name.
#
# For example, if I want to make my variable names more descriptive I can use:

# %%
# More descriptive variable names for my name and age
my_name = 'Julie'

my_age = 24

# %% [markdown]
# Variable names can also contain numbers, just as long as the first letter of the name is a letter.

# %%
# My age in year 2020 
my_age_2020 = '24'

# %% [markdown]
# Variables can also be used to hold the result of a mathematical expression.  For example:

# %%
a = 2 + 2

print(a)
# Out:
# 4

# %% [markdown]
# You can overwrite the value stored in a variable by setting it equal to a new value.  For example:

# %%
# Assigning a value to the variable a
a = 'Julie'

# Print the value stored in a
print (a)

# Assign a new value to the variable a
a = 'Adam'

# Print the new value stored in a
print(a)

# %% [markdown]
# If you want to keep the values stored in your variables, make sure you are careful about not overwriting them.  Use unique variable names for each value you want to keep!

# %% [markdown]
# #### Problem!
#
# In the box below create three variables.
# 1. The first variable needs to hold a string (remember to use single quotes!)
# 2. The second variable needs to hold a number
# 3. The third variable should hold the result of a mathematical expression
#
# After you assign values to all three of your variables, use three print statements to display the values your variables are holding.
#
# Finally, overwrite the value stored on one of your variables so it holds a new value.  Print out the new value of the variable.
#
# Remember to use descriptive variable names and use comments to tell what your code is doing!

# %% [markdown]
# ### Advanced Printing
#
#
# To make your print statements more clear, you can combine strings and variables in print statements!  To do this you put both things you want to print inside the parenthesis of the print statement (in the order you want them to print) and separate them with a comma.  For example:

# %%
a = 3

print('The value of a is', a)
# Out:
# The value of a is 3

# %% [markdown]
# You can also do this with more than one variable, you just need to have commas between the individual parts.

# %%
a = 3
b = 4

print ('The value of a is', a, 'and the value of b is', b)
# Out:
# The value of a is 3 and the value of b is 4

# %% [markdown]
# #### Problem!
#
# Create three variables.  These can contain any values you want.  Then, print out all three variables with descriptive strings to describe what is being printed.  You can use one print statement or three print statements.
#
# Remember to use descriptive variable names and comments!

# %% [markdown]
# ### User Input
#
# A common thing to do when writing a program is to ask the person using your code for some type of input.  Python does this by having the user type into the console (the place below your code where things are printed).  You can store a users input in a variable and use it later.
#
# Python asks for user input using this bit of code : `input()`.  You can set this bit of code equal to a variable if you want to store it.  For example:

# %%
user_input = input()
# Out:
# hi

# %% [markdown]
# To give the above variable a value, run the cell and then type something into the box that appears below the code.  Press Enter after typing in the value!
#
# Once we have stored the user input into a variable (`user_input`) we can print the variable to see what value it holds.

# %%
print (user_input)
# Out:
# 6

# %% [markdown]
# Python saves the input as a _string_ even if its a number. If you want Python to save the input as a number you have to specifically tell it to make a *conversion*.
#
# For example if you want to save the inputted number as an integer (a number without a decimal point) you can place the `input()` inside parenthesis with `int` before the parenthesis.

# %%
a = int(input())

# %% [markdown]
# If you want to save your number as a float (a number with a decimal point) you can use the same format but replace `int` with `float`.

# %%
a = float(input())

# %% [markdown]
# #### Problem!
#
# Create a code in the box below that asks the user to input an integer (a number without a decimal point).  Save the inputed number as a variable (with the appropriate type conversion) and then print the number.

# %% [markdown]
# ### Project!
#
# In the code box below you will be creating your own program!
#
# Step 1) Write a program that will ask your user for at least three different inputs (with at least one input being a number).  For example you could ask for the user's name, age, and favorite animal.
#
# Step 2) Do some type of math with the number that is inputted (remember to make the conversion!) and save the result in a new variable.  For example, you could calculate how old the person would be in 3 years and save this in the variable `age_in_3years`.
#
# Step 3) Display all the variables (including the variable you changed) in prints statements with descriptive strings.
#
# Step 4) Have someone else test your program!
